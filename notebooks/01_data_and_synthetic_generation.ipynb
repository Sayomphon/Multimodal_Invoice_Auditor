# %% [markdown]
# # 01 — Data and synthetic generation
# Notebook นี้ทำหน้าที่ orchestration เท่านั้น logic อยู่ใน `src/invoice_auditor`.

# %%
from pathlib import Path
from invoice_auditor.synthetic_generator import generate_dataset

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
manifest = generate_dataset(PROJECT_ROOT / 'data/synthetic', count=6, seed=42, overwrite=True)
manifest
